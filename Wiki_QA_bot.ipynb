# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
from nltk.tokenize import TweetTokenizer
tt = TweetTokenizer()

# %%
import pandas as pd
df = pd.read_table('/content/gdrive/My Drive/WikiQA-train.tsv')

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchtext.legacy.data import Field, BucketIterator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-c7576630b131> in <module>
#       2 import torch.nn as nn
#       3 import torch.optim as optim
# ----> 4 from torchtext.legacy.data import Field, BucketIterator
#
# ModuleNotFoundError: No module named 'torchtext.legacy'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
df.head(10)
# Out:
#   QuestionID                                           Question DocumentID  \
# 0         Q1                      how are glacier caves formed?         D1
# 1         Q1                      how are glacier caves formed?         D1
# 2         Q1                      how are glacier caves formed?         D1
# 3         Q1                      how are glacier caves formed?         D1
# 4         Q1                      how are glacier caves formed?         D1
# 5         Q2  How are the directions of the velocity and for...         D2
# 6         Q2  How are the directions of the velocity and for...         D2
# 7         Q2  How are the directions of the velocity and for...         D2
# 8         Q2  How are the directions of the velocity and for...         D2
# 9         Q2  How are the directions of the velocity and for...         D2
#
#      DocumentTitle SentenceID  \
# 0     Glacier cave       D1-0
# 1     Glacier cave       D1-1
# 2     Glacier cave       D1-2
# ...

# %%
df.tail(10)
# Out:
#       QuestionID                             Question DocumentID  \
# 20337      Q3043        what is section eight housing      D2807
# 20338      Q3043        what is section eight housing      D2807
# 20339      Q3043        what is section eight housing      D2807
# 20340      Q3043        what is section eight housing      D2807
# 20341      Q3043        what is section eight housing      D2807
# 20342      Q3043        what is section eight housing      D2807
# 20343      Q3043        what is section eight housing      D2807
# 20344      Q3044  what is the main type of restaurant      D2808
# 20345      Q3046     what is us dollar worth based on      D2810
# 20346      Q3046     what is us dollar worth based on      D2810
#
#                              DocumentTitle SentenceID  \
# 20337                  Section 8 (housing)    D2807-3
# 20338                  Section 8 (housing)    D2807-4
# 20339                  Section 8 (housing)    D2807-5
# ...

# %%
import string
def tokenize_sentence(text):
    no_punct=[words for words in text if words not in string.punctuation]
    words_wo_punct=''.join(no_punct)
    return words_wo_punct

# df['tokenized_Question']=(df['Question'].apply(lambda x: remove_punctuation(x))).apply(tt.tokenize)
# df['tokenized_Sentence']=(df['Sentence'].apply(lambda x: remove_punctuation(x))).apply(tt.tokenize)

# %%
SRC = Field(tokenize = tokenize_sentence, 
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True)
TRG = Field(tokenize = tokenize_sentence, 
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-93646ab6f177> in <module>
# ----> 1 SRC = Field(tokenize = tokenize_sentence,
#       2             init_token = '<sos>',
#       3             eos_token = '<eos>',
#       4             lower = True)
#       5 TRG = Field(tokenize = tokenize_sentence,
#
# NameError: name 'Field' is not defined

# %%
df.head(10)
# Out:
#   QuestionID                                           Question DocumentID  \
# 0         Q1                      how are glacier caves formed?         D1
# 1         Q1                      how are glacier caves formed?         D1
# 2         Q1                      how are glacier caves formed?         D1
# 3         Q1                      how are glacier caves formed?         D1
# 4         Q1                      how are glacier caves formed?         D1
# 5         Q2  How are the directions of the velocity and for...         D2
# 6         Q2  How are the directions of the velocity and for...         D2
# 7         Q2  How are the directions of the velocity and for...         D2
# 8         Q2  How are the directions of the velocity and for...         D2
# 9         Q2  How are the directions of the velocity and for...         D2
#
#      DocumentTitle SentenceID  \
# 0     Glacier cave       D1-0
# 1     Glacier cave       D1-1
# 2     Glacier cave       D1-2
# ...

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, emb_dim, hid_dim, n_layers, dropout):
        super().__init__()
        
        self.hid_dim = hid_dim
        self.n_layers = n_layers
        
        self.embedding = nn.Embedding(input_dim, emb_dim)
        
        self.rnn = nn.LSTM(emb_dim, hid_dim, n_layers, dropout = dropout)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, src):
        
        #src = [src len, batch size]
        
        embedded = self.dropout(self.embedding(src))
        
        #embedded = [src len, batch size, emb dim]
        
        outputs, (hidden, cell) = self.rnn(embedded)
        
        #outputs = [src len, batch size, hid dim * n directions]
        #hidden = [n layers * n directions, batch size, hid dim]
        #cell = [n layers * n directions, batch size, hid dim]
        
        #outputs are always from the top hidden layer
        
        return hidden, cell

# %%
class Decoder(nn.Module):
    def __init__(self, output_dim, emb_dim, hid_dim, n_layers, dropout):
        super().__init__()
        
        self.output_dim = output_dim
        self.hid_dim = hid_dim
        self.n_layers = n_layers
        
        self.embedding = nn.Embedding(output_dim, emb_dim)
        
        self.rnn = nn.LSTM(emb_dim, hid_dim, n_layers, dropout = dropout)
        
        self.fc_out = nn.Linear(hid_dim, output_dim)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, input, hidden, cell):
        
        #input = [batch size]
        #hidden = [n layers * n directions, batch size, hid dim]
        #cell = [n layers * n directions, batch size, hid dim]
        
        #n directions in the decoder will both always be 1, therefore:
        #hidden = [n layers, batch size, hid dim]
        #context = [n layers, batch size, hid dim]
        
        input = input.unsqueeze(0)
        
        #input = [1, batch size]
        
        embedded = self.dropout(self.embedding(input))
        
        #embedded = [1, batch size, emb dim]
                
        output, (hidden, cell) = self.rnn(embedded, (hidden, cell))
        
        #output = [seq len, batch size, hid dim * n directions]
        #hidden = [n layers * n directions, batch size, hid dim]
        #cell = [n layers * n directions, batch size, hid dim]
        
        #seq len and n directions will always be 1 in the decoder, therefore:
        #output = [1, batch size, hid dim]
        #hidden = [n layers, batch size, hid dim]
        #cell = [n layers, batch size, hid dim]
        
        prediction = self.fc_out(output.squeeze(0))
        
        #prediction = [batch size, output dim]
        
        return prediction, hidden, cell

# %%
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, device):
        super().__init__()
        
        self.encoder = encoder 
        self.decoder = decoder
        self.device = device
        
        assert encoder.hid_dim == decoder.hid_dim, \
            "Hidden dimensions of encoder and decoder must be equal!"
        assert encoder.n_layers == decoder.n_layers, \
            "Encoder and decoder must have equal number of layers!"
        
    def forward(self, src, trg, teacher_forcing_ratio = 0.5):
        
        #src = [src len, batch size]
        #trg = [trg len, batch size]
        #teacher_forcing_ratio is probability to use teacher forcing
        #e.g. if teacher_forcing_ratio is 0.75 we use ground-truth inputs 
        #75% of the time
        
        batch_size = trg.shape[1]
        trg_len = trg.shape[0]  
        trg_vocab_size = self.decoder.output_dim
        
        #tensor to store decoder outputs
        outputs = torch.zeros(trg_len, batch_size, trg_vocab_size).to(self.device)
        
        #last hidden state of the encoder is used as the initial hidden state of the decoder
        hidden, cell = self.encoder(src)
        
        #first input to the decoder is the <sos> tokens
        input = trg[0,:]
        
        for t in range(1, trg_len):
            
            #insert input token embedding, previous hidden and previous cell states
            #receive output tensor (predictions) and new hidden and cell states
            output, hidden, cell = self.decoder(input, hidden, cell)
            
            #place predictions in a tensor holding predictions for each token
            outputs[t] = output
            
            #decide if we are going to use teacher forcing or not
            teacher_force = random.random() < teacher_forcing_ratio
            
            #get the highest predicted token from our predictions
            top1 = output.argmax(1) 
            
            #if teacher forcing, use actual next token as next input
            #if not, use predicted token
            input = trg[t] if teacher_force else top1
        
        return outputs

# %%
# SRC = df['Question'].insert(0,'<sos>')
# SRC = df['Question'].append('<eos>')
# TRG = df['Sentence'].insert(0,'<sos>')
# TRG = df['Sentence'].append('<eos>')


INPUT_DIM = len(SRC.vocab)
OUTPUT_DIM = len(TRG.vocab)
ENC_EMB_DIM = 256
DEC_EMB_DIM = 256
HID_DIM = 512
N_LAYERS = 2
ENC_DROPOUT = 0.5
DEC_DROPOUT = 0.5

enc = Encoder(INPUT_DIM, ENC_EMB_DIM, HID_DIM, N_LAYERS, ENC_DROPOUT)
dec = Decoder(OUTPUT_DIM, DEC_EMB_DIM, HID_DIM, N_LAYERS, DEC_DROPOUT)

model = Seq2Seq(enc, dec, device).to(device)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-3d15ca2bd7f8> in <module>
# ----> 1 SRC = df['Question'].insert(0,'<sos>')
#       2 SRC = df['Question'].append('<eos>')
#       3 TRG = df['Sentence'].insert(0,'<sos>')
#       4 TRG = df['Sentence'].append('<eos>')
#       5
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'insert'

# %%
# !git version
# Out:
# git version 2.25.1

# %%
# !git clone https://github.com/adviti-mishra/Discord-ChatBot-Q-A.git
# Out:
# Cloning into 'Discord-ChatBot-Q-A'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), 658 bytes | 658.00 KiB/s, done.

# %%
# !ls
# Out:
# Discord-ChatBot-Q-A  sample_data

# %%
# %cd Discord-ChatBot-Q-A
# Out:
# /content/Discord-ChatBot-Q-A

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git add .

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# %ls
# Out:
# README.md
